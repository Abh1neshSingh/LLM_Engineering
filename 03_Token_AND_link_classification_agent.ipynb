# %%
import tiktoken
encoding = tiktoken.encoding_for_model("gpt-4.1-mini")
tokens = encoding.encode("Hi my name is Abhinesh Singh")

# %%
tokens
# Out:
# [12194, 922, 1308, 382, 3483, 71, 2028, 71, 44807]

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 12194 = Hi
# 922 =  my
# 1308 =  name
# 382 =  is
# 3483 =  Ab
# 71 = h
# 2028 = ines
# 71 = h
# 44807 =  Singh

# %%
encoding.decode([71])
# Out:
# 'h'

# %%
import os
from groq import Groq
from dotenv import load_dotenv

from openai import api_key

load_dotenv()

client = Groq(api_key=os.getenv("OPENAI_API_KEY"))

messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Ed!"}
]

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Nice to meet you, Ed! How are you doing today? Is there anything specific I can help you with or would you like to chat and see where our conversation takes us?

# %%
import os
from groq import Groq
from dotenv import load_dotenv

# load environment variables
load_dotenv()

client = Groq(api_key=os.getenv("OPENAI_API_KEY"))

messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Ed!"}
]

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Nice to meet you, Ed. How can I help you today?

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What's my name?"}
    ]

# %%
response = client.chat.completions.create(model="llama-3.1-8b-instant", messages=messages)
response.choices[0].message.content
# Out:
# "I'm happy to help you, but I'm a large language model, I don't have any information about you. I'm a new conversation each time you interact with me, so I don't have any knowledge about your name or any other personal details. If you'd like to share your name, I'd be happy to chat with you."

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Abhinesh"},
    {"role": "assistant", "content": "Hi Abhinesh! How can I assist you today?"},
    {"role": "user", "content": "What's my name?"}
    ]

# %%
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=messages

)

response.choices[0].message.content
# Out:
# 'Your name is Abhinesh.'
