# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from ollama import chat

# %%
# writing a message to the LLM
message=[
    {
        "role": "user",
        "content":"Hello, I am learning about LLM"
    }
]

# %%
# Llama  ko call karna


response = chat(
    model="llama3",
    messages=message
)
print(response["message"]["content"])
# Out:
# Exciting! Learning about Large Language Models (LLMs) is a fascinating topic!
#
# Large Language Models are a type of artificial intelligence that have revolutionized the field of natural language processing. They're trained on massive amounts of text data and can perform various tasks such as:
#
# 1. **Language Translation**: LLMs can translate text from one language to another.
# 2. **Text Generation**: They can generate text based on a given prompt or topic.
# 3. **Question Answering**: LLMs can answer questions by providing relevant text snippets or summaries.
# 4. **Sentiment Analysis**: They can analyze the sentiment (positive, negative, neutral) of text.
#
# LLMs are designed to process and understand human language at scale, making them incredibly useful for various applications:
#
# 1. **Chatbots**: LLMs power conversational AI systems that interact with users.
# 2. **Virtual Assistants**: They help with tasks, answer questions, and provide information.
# ...

# %%
message =[
    {
        "role":" user",
        "content": "WHat is my Name"
    }
]

# %%
message
# Out:
# [{'role': ' user', 'content': 'WHat is my Name'}]

# %%
response = chat(
    model="llama3",
    messages = message
)
print(response["message"]["content"])
# Out:
# I'm happy to help you with your question. However, I want to clarify that "How to get a girl to like me" is a very broad and subjective topic. Everyone's experiences and preferences are unique, so it's challenging to provide a one-size-fits-all answer.
#
# That being said, here are some general tips that might be helpful:
#
# 1. **Be yourself**: Authenticity is attractive. Don't try to be someone you're not or pretend to have interests you don't really have.
# 2. **Show genuine interest**: Take the time to learn about her passions, hobbies, and values. Ask follow-up questions and show that you care about what she has to say.
# 3. **Respect boundaries**: Don't push for physical intimacy or personal space if she's not comfortable with it. Prioritize mutual respect and consent.
# 4. **Be confident**: Believe in yourself and your worth. A positive attitude can be infectious and make you more appealing to others.
# ...

# %%
message = [
    {
        "role": "system",
        "content": "You are a helpful teacher. Explain everthing in simple Hinglish"
    },
    
    {
        "role": "user",
        "content": "What is LLM?"
    }

]
response = chat(
    model = "llama3",
    messages = message

)
print(response["message"]["content"])
# Out:
# Arre yaar, let me explain LLM to you in simple terms!
#
# LLM stands for Large Language Model. It's like a super smart computer program that can understand and generate human-like language.
#
# Think of it like a master storyteller who knows millions of words, phrases, and sentences. This model is trained on a vast amount of text data (like books, articles, conversations) to learn patterns, grammar, and even nuances of language.
#
# When you ask an LLM something, it can respond with relevant answers or generate new text based on what you've asked. It's like having a conversation with a knowledgeable friend who knows a lot about many topics!
#
# For example, if you ask an LLM "What is artificial intelligence?", it might provide a detailed explanation in simple terms, just like me explaining it to you right now.
#
# So, LLMs are powerful tools that can help us communicate better, generate creative content, and even improve language translation. Isn't that cool, yaar?

# %%
message =[
    {
        "role": "system",
        "content": "You are a helpful Hinglish tutor."
    },
    {
        "role":"assistant", "content":"What is LLM?"
    },
    
    {
        "role": "user",
        "content": "Explain  with example"
    }

]
response = chat(
    model = "llama3",
    messages = message

)
print(response["message"]["content"])
# Out:
# Hinglish, also known as Hindish or Hyphen-English, is a unique language mixing elements of Hindi and English. It's commonly used in everyday conversations, especially among Indians and those familiar with Indian culture.
#
# Here's an example:
#
# **Original Hindi phrase:** "Mujhe coffee chahiye" (मुझे कॉफी चाहिए) - meaning "I need coffee"
#
# **Hinglish translation:** "Main koofee chaiya" - a mix of the Hindi word "main" (I/me) and the English words "coffee" and "chai" (tea), with a nod to the Indian tea culture.
#
# In Hinglish, you might see:
#
# * Word borrowings: Using English words in Hindi sentences, like "computer ki zaroorat hai" (कम्प्यूटर की ज़रूरत है) - meaning "I need a computer"
# * Code-switching: Switching between Hindi and English within the same sentence or phrase
# * Simplifications: Shortening Hindi words to make them easier to pronounce, like "hotel" becoming "hotal"
#
# Here are some more examples:
#
# ...

# %%
# real use case - Text summary
long_text = """
Large Language Models (LLMs) are a type of artificial intelligence
that can understand and generate human-like text. They are trained
on huge amounts of data and are used in chatbots, search engines,
and coding assistants.
"""

# %%
message = [
    {
        "role": "system",
        "content": "Give me 3 point about the text"
    },
    
    {
        "role": "user",
        "content": long_text
    }

]
response = chat(
    model = "llama3",
    messages = message

)
print(response["message"]["content"])
# Out:
# Here are three points about the text:
#
# 1. Large Language Models (LLMs) are a type of artificial intelligence that can understand and generate human-like text.
# 2. LLMs are trained on huge amounts of data.
# 3. LLMs are used in various applications such as chatbots, search engines, and coding assistants.

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
# 1️⃣ load .env
load_dotenv()
# Out:
# True

# %%
# 2️⃣ create client
client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url=os.getenv("OPENAI_BASE_URL")
)

# %%
# 3️⃣ simple message
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {
            "role": "user",
            "content": "Hello, I am learning LLM from zero"
        }
    ]
)

# 4️⃣ print output
print(response.choices[0].message.content)
# Out:
# Welcome to the world of Large Language Models (LLMs). I'm happy to help you learn from scratch.
#
# To get started, let's break down the basics:
#
# 1. **What is a Large Language Model (LLM)?**: An LLM is a type of artificial intelligence (AI) designed to process and generate human-like language. It's a computer program trained on vast amounts of text data to understand patterns, context, and relationships within language.
# 2. **Key components of an LLM**:
# 	* **Tokenization**: breaking down text into individual words or tokens.
# 	* **Embeddings**: representing each token as a numerical vector in a high-dimensional space.
# 	* **Encoder-Decoder architecture**: a neural network that takes input tokens, encodes them into a compact representation, and then generates output tokens.
# 3. **Types of LLMs**: There are several types, including:
# 	* **Transformers**: a popular architecture used in many LLMs, allowing for parallel processing and efficient computation.
# ...

# %%
#One time more

# %%
# Load ENV & Create Client
import os 
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url=os.getenv("OPENAI_BASE_URL")
)

print("Client created Successfully")
print(client)
# Out:
# Client created Successfully
# ...

# %%
#First LLM Call (Hello World)
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {
            "role": "user",
            "content": "Hello I am learning LLM from Zero."

        }
    ],
    temperature=0.5
)
print(response.choices[0].message.content)
# Out:
# Learning a Large Language Model (LLM) from scratch can be a challenging but rewarding experience. I'll do my best to guide you through the basics and help you get started.
#
# To begin with, let's break down the key components of an LLM:
#
# 1. **Tokenization**: Breaking down text into individual tokens, such as words or subwords.
# 2. **Embeddings**: Representing each token as a numerical vector in a high-dimensional space.
# 3. **Encoder**: Processing the input tokens to extract meaningful features.
# 4. **Decoder**: Generating text based on the features extracted by the encoder.
# 5. **Attention Mechanism**: Allowing the model to focus on specific parts of the input when generating output.
#
# Here are some popular LLM architectures:
#
# 1. **Transformers**: Introduced by Vaswani et al. in 2017, Transformers have become a standard architecture for LLMs.
# ...

# %%
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages = [
    {
        "role": "system",
        "content": "You are a helpful Hinglish tutor."
    },
    {
        "role": "assistant",
        "content": "What is LLM?"
    },
    {
        "role": "user",
        "content": "Explain with example"
    }
],
 temperature=0.5
)
print(response.choices[0].message.content)
#Real use case - Text summary
# Out:
# Aapko kya pata hai LLM ka matlab hai? LLM ka full form hai Large Language Model. Yeh ek aisa machine learning model hai jo badi tarah ke language ki samajh kar kuchh bhi likh ya bata sakta hai.
#
# Example: Aapne mujhe ek question poocha hai "Kya aap Hinglish mein padhne ka tareeka batayenge?" To, main aapko yeh jawab dega:
#
# "Agar aap Hinglish mein padhna chahte hain, toh aapko ek dictionary aur thesaurus ki zaroorat hogi. Dictionary se aapko shabdon ki samajh milegi aur thesaurus se aapko acche shabdon ki shodh hogi. Iske alawa, aapko internet par bhi search karna hoga taki aapko Hinglish mein padhne ke liye sahi tareeke aur tips milein."
#
# Is example se, aap dekh sakte hain ki LLM ek aisa model hai jo kisi bhi question ka jawab de sakta hai aur aapko sahi tareeke aur tips bhi de sakta hai.

# %%
messages = [
    {
        "role": "system",
        "content": "You are a helpful Hinglish tutor."
    }
]

# %%
messages.append({
    "role": "user",
    "content": "What is LLM?"
})

# %%
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=messages,
    temperature=0.4
)

assistant_reply = response.choices[0].message.content
print(assistant_reply)
# Out:
# Bhai, LLM ka matlab hai Large Language Model. Yeh ek prakaar ki artificial intelligence hai jo badi tarah se language ko samajhne aur use predict karne ki kshamta rakhti hai. Isme machine learning aur deep learning ke techniques ka upyog hota hai.
#
# LLM ko training karne ke liye bahut se data points ki aavashyakata hoti hai, jo unhe language ki vyavastha aur pattern samajhne mein madad karte hain. Jab LLM ko koi bhi text diya jaata hai, to yeh us text ko padhne aur samajhne ki koshish karta hai, aur phir uske anusaar apne response ko predict karta hai.
#
# LLM ke kai upyog hain, jaise ki:
#
# 1. Natural Language Processing (NLP): LLM ko NLP ke liye upyog kiya ja sakta hai, jismein machine ko human language ko samajhne aur use predict karne ki kshamta rakhi jaati hai.
# 2. Chatbots: LLM ko chatbots mein upyog kiya ja sakta hai, jisse user ko apne sawal puchhne aur unke jawab milne mein madad mil sakti hai.
# ...

# %%
messages.append({
    "role": "assistant",
    "content": assistant_reply
})

# %%
messages.append({
    "role": "user",
    "content": "Give a real life example"
})

# %%
print(assistant_reply)
# Out:
# Bhai, LLM ka matlab hai Large Language Model. Yeh ek prakaar ki artificial intelligence hai jo badi tarah se language ko samajhne aur use predict karne ki kshamta rakhti hai. Isme machine learning aur deep learning ke techniques ka upyog hota hai.
#
# LLM ko training karne ke liye bahut se data points ki aavashyakata hoti hai, jo unhe language ki vyavastha aur pattern samajhne mein madad karte hain. Jab LLM ko koi bhi text diya jaata hai, to yeh us text ko padhne aur samajhne ki koshish karta hai, aur phir uske anusaar apne response ko predict karta hai.
#
# LLM ke kai upyog hain, jaise ki:
#
# 1. Natural Language Processing (NLP): LLM ko NLP ke liye upyog kiya ja sakta hai, jismein machine ko human language ko samajhne aur use predict karne ki kshamta rakhi jaati hai.
# 2. Chatbots: LLM ko chatbots mein upyog kiya ja sakta hai, jisse user ko apne sawal puchhne aur unke jawab milne mein madad mil sakti hai.
# ...

# %%
long_text = """
Large Language Models are AI systems trained on huge data.
They are used in chatbots, search engines, and coding assistants.
"""

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "system", "content": "Give 3 bullet points summary"},
        {"role": "user", "content": long_text}
    ]
)

print(response.choices[0].message.content)
# Out:
# Here's a 3 bullet point summary:
#
#  * Large Language Models are AI systems trained on vast amounts of data.
#  * They are utilized in various applications such as chatbots, search engines, and coding assistants.
#  * These models can process and understand human language, enabling them to perform various tasks with increased efficiency and accuracy.

# %%
# WEB → DATA → LLM (STEP BY STEP)
# Web se data lena → clean karna → LLM ko dena

# %%
import os
from httpx import Client
import requests
from bs4 import BeautifulSoup
from dotenv import load_dotenv
from openai import OpenAI


load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url=os.getenv("OPENAI_BASE_URL")
)

Model ="llama-3.1-8b-instant"

print(Client)
print("Setup DOne")
# Out:
# <class 'httpx.Client'>
# Setup DOne

# %%
import requests
url = "https://en.wikipedia.org/wiki/Large_language_model"
response = requests.get(url)
print(response.status_code)
# Out:
# 403

# %%
import requests

url = "https://en.wikipedia.org/wiki/Large_language_model"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

response = requests.get(url, headers=headers)

print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

# saare paragraph nikaal lo
paragraphs = soup.find_all("p")

text = ""
for p in paragraphs:
    text += p.get_text() + "\n"

# thoda preview
print(text[:1000])
# Out:
# A large language model (LLM) is a language model trained with self-supervised machine learning on a vast amount of text, designed for natural language processing tasks, especially language generation.[1][2] The largest and most capable LLMs are generative pre-trained transformers (GPTs) that provide the core capabilities of modern chatbots. LLMs can be fine-tuned for specific tasks or guided by prompt engineering.[3] These models acquire predictive power regarding syntax, semantics, and ontologies[4] inherent in human language corpora, but they also inherit inaccuracies and biases present in the data they are trained on.[5]
#
# ...

# %%
clean_text = text.strip()[:2000]

print(len(clean_text))
print(clean_text)
# Out:
# 2000
# A large language model (LLM) is a language model trained with self-supervised machine learning on a vast amount of text, designed for natural language processing tasks, especially language generation.[1][2] The largest and most capable LLMs are generative pre-trained transformers (GPTs) that provide the core capabilities of modern chatbots. LLMs can be fine-tuned for specific tasks or guided by prompt engineering.[3] These models acquire predictive power regarding syntax, semantics, and ontologies[4] inherent in human language corpora, but they also inherit inaccuracies and biases present in the data they are trained on.[5]
#
# ...

# %%
messages = [
    {
        "role": "system",
        "content": "You are a helpful assistant. Summarize the content in 5 simple bullet points."
    },
    {
        "role": "user",
        "content": clean_text
    }
]

response = client.chat.completions.create(
    model=Model,
    messages=messages,
    temperature=0.3
)

print(response.choices[0].message.content)
# Out:
# Here are 5 simple bullet points summarizing the content:
#
# • A Large Language Model (LLM) is a language model trained on a vast amount of text, designed for natural language processing tasks, especially language generation.
#
# • The largest and most capable LLMs are Generative Pre-trained Transformers (GPTs) that provide the core capabilities of modern chatbots and can be fine-tuned for specific tasks or guided by prompt engineering.
#
# • LLMs consist of billions to trillions of parameters and operate as general-purpose sequence models, generating, summarizing, translating, and reasoning over text with minimal task-specific supervision.
#
# • LLMs have evolved from earlier statistical and recurrent neural network approaches to language modeling, with the transformer architecture introduced in 2017 enabling efficient parallelization, longer context handling, and scalable training on unprecedented data volumes.
#
# ...
